# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')

print(df[df.duplicated()])
df.drop_duplicates(inplace=True)
print(df[df.duplicated()])
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p = df[df['Title']=="House of cards"]
print(p)
print(list(p['Show_Id']))
print(list(p['Director']))
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []
# []
# []

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p = df['Release_Date'].value_counts().max()
p
# Out:
# 118

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p = df['Show_Id'].unique()

len(list(p))
# Out:
# 7787

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')

df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# df["Date_N"]=pd.to_datetime(df["Release_Date"])
import pandas as pd
df = pd.read_csv('netflix_data.csv')

# df = pd.DataFrame({'InsertedDate': pd.to_datetime(df["Release_Date"])})

# df['Year'] = df['InsertedDate'].dt.strftime('%Y')
# print(df)
# df['Year'] = df["Release_Date"].dt.strftime('%Y')


df['year'] = pd.DatetimeIndex(df['Release_Date']).year
df[(df['Category']=='Movie') &  (df['year']==2020.0)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p=df[(df['Country']=='India') & (df['Category']=='TV Show')]
p['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p = df['Director'].value_counts()
p.head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p=df[(df['Country']=='Unite Kingdom') |( (df['Category']=='Movie') & (df['Type']=='Comedies'))]
p['Title']
# Out:
# 33                     #realityhigh
# 72                         17 Again
# 84                        21 & Over
# 148            A Bad Moms Christmas
# 174     A Futile and Stupid Gesture
#                    ...
# 7341           Undercover Brother 2
# 7590              Where's the Money
# 7623                      Wild Oats
# 7634                   Wine Country
# 7664                        Work It
# Name: Title, Length: 97, dtype: object

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p = df[(df['Cast']=='Tom Cruise')]
p['Title'].count()
# Out:
# 0

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
list(df['Rating'].unique())
# Out:
# ['TV-MA',
#  'R',
#  'PG-13',
#  'TV-14',
#  'TV-PG',
#  'NR',
#  'TV-G',
#  'TV-Y',
#  nan,
#  'TV-Y7',
#  'PG',
#  'G',
#  'NC-17',
#  'TV-Y7-FV',
#  'UR']

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p=df[(df['Country']=='Canada') & (df['Category']=='Movie') & (df['Rating']=='TV-14')]
p['Title'].count()
# Out:
# 11

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
x = df['Release_Date']

    
p = df[(df['Release_Date'] > str(2020) ) &  (df['Category']=='TV Show') &  (df['Rating']=='R')]
p
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description
# 4497  A series of incidents in Afghanistan set compl...
# 6437  Trapped at a stagecoach stop as a storm rages ...

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p=df[(df['Category']=='TV Show')]

country= p['Country'].value_counts().head()
country
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')
p=df.sort_values('Release_Date')
p
# Out:
#      Show_Id Category                         Title Director  \
# 6673   s6672  TV Show           The Minimighty Kids      NaN
# 4261   s4262  TV Show                     Mr. Young      NaN
# 3730   s3731  TV Show                     Lost Girl      NaN
# 6247   s6247  TV Show                  The Cravings      NaN
# 1315   s1316  TV Show                   Chewing Gum      NaN
# ...      ...      ...                           ...      ...
# 3374   s3375  TV Show                      Kikoriki      NaN
# 3492   s3493  TV Show           La Familia P. Luche      NaN
# 3946   s3947  TV Show                         Maron      NaN
# 5138   s5138  TV Show                  Red vs. Blue      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho      NaN
#
#                                                    Cast         Country  \
# 6673                                                NaN          France
# 4261  Brendan Meyer, Matreya Fedor, Gig Morton, Kurt...          Canada
# ...
